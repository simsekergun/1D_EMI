# %% [markdown]
# <a href="https://colab.research.google.com/github/simsekergun/1D_EMI/blob/master/tree/main/HW/DATA601Sp22_HW01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## DATA 601 - Spring 2022
# ### Homework Assignment 1
#
# #### Due-date: February 10, 11:59 pm
#
# Please return your notebook (by uploading as a *.ipynb file) via Blackboard. The name of your notebook should be in the following format: YourLastname_HW01.ipynb (e.g. Simsek_HW01.ipyn).
#
# Make sure that your code is in a working condition when you restart the kernel. Notebooks are great tools for exploration but we should be very careful as we are writing codes.
#
#
# 0. For this homework, you will install a module called "names". Please visit [https://pypi.org/project/names/](https://pypi.org/project/names/) to learn how to use this module to create random names. To install this "names" module, please copy and paste the following command in your first cell and press shift+enter <br>
# <code>!pip install names </code>
#
# 1. [<span style="color: red;">5 points</span>] After successful installation, use the "get_first_name" function in the "names" module and create a list of 8 first-names. Name of this list should be "fname".
# - Print your list and make sure that you indeed have 8 names in your list.
# - (i) Remove the last "first-name" from your "fname" list.
# - (ii) Insert a new first-name between the first and second first-names in the list.
# - (iii) Remove the third "first-name".
# - (iv)  Generate three random first names, print them, and then add three first names at the end of your "fname" list using the "append" command.
# - (v) Remove those last three first names. Create a secondary a list of first-names with three new first-names. Add these three at the end of your "fname" list with the "extend" method. Comment when we should use "append" and we should use "extend".
#
# 2. [<span style="color: red;">1 points</span>] Use the "get_last_name" function in the "names" module and create a list of 10 last names. Name it "lnames". Sort it alphabetically.
#
# 3. [<span style="color: red;">4 points</span>] For this step, you will use the "<code>randint</code>" function from the "<code>random</code>" module to create random integers. You can learn more about this module at [https://docs.python.org/3/library/random.html](https://docs.python.org/3/library/random.html). To import the "<code>randint</code>" function from the "<code>random</code>" module, please type <code> from random import randit</code> in a cell, and press shift+enter.
#
# Then
#  - (i) Create 10 random birth-years between 1950 and 2021. Name it "byears".
#  - (ii) Create 10 random birth-months between 1 and 12. Name it "bmonths".
#  - (iii) Create 10 random birth-days between 1 and 31. Name it "bdays". Replace the random integer if it is not realistic, according to "bmonths" (e.g. February 29, June 31, etc).
#  - (iv) Create 10 random Credit-Scores between 100 and 800. Create a list of "CreditApproval" with "Yes" if the credit-score is higher than 650, "No" otherwise. Make sure that someone can't get a credit if they are 17 years old or younger, even if their credit-score is higher than 650.
#
# 4. [<span style="color: red;">3 points</span>] Create a dictionary for these 10 people with first-name, last-name (again, you will need to use the <code>names</code> module to create random first and last names), birth-year, birth-month, birth-day, CreditApproval (e.g. [fname: Michael, lname: Jackson, byear: 1958, bmonth: 8, bday: 29, creditapproval:yes],[...])
#
# 5. <b>BONUS QUESTION</b> [<span style="color: red;">7 points</span>] Review the Lecture 2 materials [part-2](https://github.com/simsekergun/DATA601/tree/main/Lecture02_Python_Programming). Save the dictionary you created in the previous question as a csv file. The name of this csv file should start your first name, e.g. <code>Ergun_HW1.csv</code>. Then open and read this csv file using csv module's reader function. This is how my csv file looks like
#
# ![image.png](data:image/png;base64,...)
